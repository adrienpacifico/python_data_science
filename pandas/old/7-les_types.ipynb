# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/basics.html?highlight=dtype#dtypes

# %%
import pandas as pd

# %% [markdown]
# `float` nombre à virgule, ou entiers avec na
# `int` integer sans NA
# `object` tout type d'objets (mixed dtypes entre autre).

# %% [markdown]
# Ils sont souvent suivit d'un nombre qui indique le nombre de bit consacré à stocker de la donnée.

# %% [markdown]
# [la documentation numpy](https://numpy.org/doc/stable/user/basics.types.html)

# %% [markdown]
# Et plus le type est petit, moins il prend de vive (ou sur disque en fonction du format de stockage).

# %%
s =pd.Series(list(range(10**7)))

# %%
s.memory_usage()
# Out:
# 80000128

# %%
s.astype("int32").memory_usage()
# Out:
# 40000128

# %%
s.astype("float32").memory_usage()
# Out:
# 40000128

# %% [markdown]
# ![image.png](attachment:b0aca193-eaf8-4b65-afc4-10ad788f219d.png)

# %% [markdown]
# ### Exemple lecture csv

# %%
df = pd.read_csv(
    "https://raw.githubusercontent.com/adrienpacifico/python_data_science/main/Download/2019_extract.txt",
                 sep="|")
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (0,1,2,3,4,5,6,7,11,16,18,19,20,22,23,24,26,28,30,32,33,34,35,37,38,39,42) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100006 entries, 0 to 100005
# Data columns (total 43 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Code service CH             1 non-null       object
#  1   Reference document          1 non-null       object
#  2   1 Articles CGI              1 non-null       object
#  3   2 Articles CGI              1 non-null       object
#  4   3 Articles CGI              1 non-null       object
#  5   4 Articles CGI              1 non-null       object
#  6   5 Articles CGI              1 non-null       object
#  7   No disposition              100006 non-null  object
#  8   Date mutation               100006 non-null  object
#  9   Nature mutation             100006 non-null  object
#  10  Valeur fonciere             99017 non-null   object
#  11  No voie                     53875 non-null   object
#  12  B/T/Q                       3652 non-null    object
#  13  Type de voie                49978 non-null   object
#  14  Code voie                   99368 non-null   object
#  15  Voie                        99358 non-null   object
#  16  Code postal                 99366 non-null   object
#  17  Commune                     100006 non-null  object
#  18  Code departement            100006 non-null  object
#  19  Code commune                100006 non-null  object
#  20  Prefixe de section          2124 non-null    object
#  21  Section                     99995 non-null   object
#  22  No plan                     100006 non-null  object
#  23  No Volume                   222 non-null     object
#  24  1er lot                     28552 non-null   object
#  25  Surface Carrez du 1er lot   9393 non-null    object
#  26  2eme lot                    7041 non-null    object
#  27  Surface Carrez du 2eme lot  2940 non-null    object
#  28  3eme lot                    923 non-null     object
#  29  Surface Carrez du 3eme lot  207 non-null     object
#  30  4eme lot                    328 non-null     object
#  31  Surface Carrez du 4eme lot  52 non-null      object
#  32  5eme lot                    139 non-null     object
#  33  Surface Carrez du 5eme lot  20 non-null      object
#  34  Nombre de lots              100006 non-null  object
#  35  Code type local             51374 non-null   object
#  36  Type local                  51374 non-null   object
#  37  Identifiant local           1 non-null       object
#  38  Surface reelle bati         51266 non-null   object
#  39  Nombre pieces principales   51266 non-null   object
#  40  Nature culture              70944 non-null   object
#  41  Nature culture speciale     2580 non-null    object
#  42  Surface terrain             70944 non-null   object
# dtypes: object(43)
# memory usage: 32.8+ MB

# %%
df.shape[0]/10**6
# Out:
# 0.100006

# %% [markdown]
# On voit que la surface du premier lot n'est pas une float

# %%
df.iloc[:,25]
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 100001      NaN
# 100002      NaN
# 100003    44,69
# 100004      NaN
# 100005      NaN
# Name: Surface Carrez du 1er lot, Length: 100006, dtype: object

# %% [markdown]
# ##### On peut convertir un dtype sur un dtype différent

# %%
df["Valeur fonciere"].str.replace(",",".").head().astype("float")
# Out:
# 0    8000.0
# 1    2175.0
# 2    2175.0
# 3    2175.0
# 4    2175.0
# Name: Valeur fonciere, dtype: float64

# %% [markdown]
# ⚠️ Il n'existe aucun mécanisme pour vérifier que la conversion se passe bien...

# %%
s = pd.Series(list(range(10**7)))

# %%
s.astype("int8")
# Out:
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
#           ...
# 9999995    123
# 9999996    124
# 9999997    125
# 9999998    126
# 9999999    127
# Length: 10000000, dtype: int8
