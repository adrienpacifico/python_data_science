# %%
import pandas as pd
import numpy as np

# %%
#https://www.data.gouv.fr/fr/datasets/frequentation-des-musees-de-france/
df = pd.read_csv(
    "https://www.data.gouv.fr/fr/datasets/r/81e9e4c0-296d-46b0-9c49-9d092c09dcc5")

# %% [markdown]
# ### Découvrir une table

# %% [markdown]
# #### Regarder rapidement les données.

# %% [markdown]
# On a les 5 premières lignes et les 5 dernières si la table est assez grande.

# %%
df
# Out:
#            id        osm_id  \
# 0     0105302           NaN
# 1     0119201  1.357668e+09
# 2     0128301  1.536397e+09
# 3     0319002           NaN
# 4     0701001  4.424167e+09
# ...       ...           ...
# 1156  8400701  8.378474e+07
# 1157  8403503  5.111377e+09
# 1158  8403502           NaN
# 1159  8412301  7.494836e+08
# 1160  8413701  8.854919e+07
#
#                                                    name number  \
# 0                 Musée Départemental des Pays De l'Ain    NaN
# 1                                   Musée Archéologique    NaN
# 2                   Musée du Peigne et de la Plasturgie    NaN
# 3     Centre National du Costume de Scène et de la S...    NaN
# 4                           Musée Vivarois César Filhol     15
# ...                                                 ...    ...
# 1156         Muséum d'Histoire Naturelle Esprit Requien     27
# 1157                                        Musée Jouve    NaN
# ...

# %% [markdown]
# #### Les premières lignes

# %%
df.head()
# Out:
#         id        osm_id                                               name  \
# 0  0105302           NaN              Musée Départemental des Pays De l'Ain
# 1  0119201  1.357668e+09                                Musée Archéologique
# 2  0128301  1.536397e+09                Musée du Peigne et de la Plasturgie
# 3  0319002           NaN  Centre National du Costume de Scène et de la S...
# 4  0701001  4.424167e+09                        Musée Vivarois César Filhol
#
#   number                         street postal_code             city country  \
# 0    NaN                            NaN         NaN  BOURG-EN-BRESSE  France
# 1    NaN              Place de l'Église       01580         Izernore  France
# 2    NaN         Rue Capitaine Montreal       01100          Veyziat  France
# 3    NaN                            NaN         NaN          MOULINS  France
# 4     15  Rue Jean-Baptiste Bechetoille       07100          Annonay  France
#
# ...

# %%
df.head(2)
# Out:
#         id        osm_id                                   name number  \
# 0  0105302           NaN  Musée Départemental des Pays De l'Ain    NaN
# 1  0119201  1.357668e+09                    Musée Archéologique    NaN
#
#               street postal_code             city country country_code status  \
# 0                NaN         NaN  BOURG-EN-BRESSE  France           fr   open
# 1  Place de l'Église       01580         Izernore  France           fr   open
#
#          lat       lon  website  phone  fax  year  \
# 0        NaN       NaN      NaN    NaN  NaN  2018
# 1  46.220134  5.554812      NaN    NaN  NaN  2018
#
#                                             stats                   tags  \
# 0        payant:0;gratuit:0;label-date:01/02/2003  label:musee de france
# 1  payant:1644;gratuit:2174;label-date:01/02/2003  label:musee de france
#
#    description
# 0          NaN
# 1          NaN

# %% [markdown]
# ##### Les dernières lignes

# %%
df.tail(2)
# Out:
#            id       osm_id                               name number  \
# 1159  8412301  749483617.0                    Musée Municipal    NaN
# 1160  8413701   88549191.0  Musée Archéologique Théo Desplans    NaN
#
#             street postal_code               city country country_code status  \
# 1159  Rue du Musée       84390              Sault  France           fr   open
# 1160    Rue Burrus       84110  Vaison-la-Romaine  France           fr   open
#
#             lat       lon  website  phone  fax  year  \
# 1159  44.091141  5.408472      NaN    NaN  NaN  2018
# 1160  44.242854  5.074631      NaN    NaN  NaN  2018
#
#                                                 stats                   tags  \
# 1159       payant:0;gratuit:425;label-date:01/02/2003  label:musee de france
# 1160  payant:59378;gratuit:9957;label-date:01/02/2003  label:musee de france
#
#       description
# 1159          NaN
# 1160          NaN

# %% [markdown]
# #### Quelques lignes prises au hasard.

# %%
df.sample(n=5, random_state=42)
# Out:
#            id        osm_id                                    name number  \
# 538   6754401  1.672636e+08                        Musée Westercamp    NaN
# 673   4410901  6.742735e+06   Muséum d'Histoire Naturelle de Nantes     12
# 578   9201201           NaN                 Musée des Années Trente    NaN
# 242   8400704  1.490236e+09       Musée Calvet (et musée Lapidaire)    NaN
# 1063  5012903           NaN  Musée de la Guerre et de la Libération    NaN
#
#                      street postal_code                   city country  \
# 538            Rue du Musée       67160            Wissembourg  France
# 673            Rue Voltaire       44000                 Nantes  France
# 578                     NaN         NaN   BOULOGNE-BILLANCOURT  France
# 242   Cours du Musée Calvet       84000                Avignon  France
# 1063                    NaN         NaN  CHERBOURG-EN-COTENTIN  France
#
#      country_code status        lat       lon  website  phone  fax  year  \
# ...

# %%
#### Pour qu'elles soient mise dans l'odre
df.sample(n=5, random_state=42).sort_index()
# Out:
#            id        osm_id                                    name number  \
# 242   8400704  1.490236e+09       Musée Calvet (et musée Lapidaire)    NaN
# 538   6754401  1.672636e+08                        Musée Westercamp    NaN
# 578   9201201           NaN                 Musée des Années Trente    NaN
# 673   4410901  6.742735e+06   Muséum d'Histoire Naturelle de Nantes     12
# 1063  5012903           NaN  Musée de la Guerre et de la Libération    NaN
#
#                      street postal_code                   city country  \
# 242   Cours du Musée Calvet       84000                Avignon  France
# 538            Rue du Musée       67160            Wissembourg  France
# 578                     NaN         NaN   BOULOGNE-BILLANCOURT  France
# 673            Rue Voltaire       44000                 Nantes  France
# 1063                    NaN         NaN  CHERBOURG-EN-COTENTIN  France
#
#      country_code status        lat       lon  website  phone  fax  year  \
# ...

# %% [markdown]
# #### Avoir des informations techiques.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1161 entries, 0 to 1160
# Data columns (total 19 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1161 non-null   object
#  1   osm_id        917 non-null    float64
#  2   name          1161 non-null   object
#  3   number        196 non-null    object
#  4   street        890 non-null    object
#  5   postal_code   905 non-null    object
#  6   city          1160 non-null   object
#  7   country       1161 non-null   object
#  8   country_code  1161 non-null   object
#  9   status        1161 non-null   object
#  10  lat           917 non-null    float64
#  11  lon           917 non-null    float64
#  12  website       0 non-null      float64
#  13  phone         0 non-null      float64
#  14  fax           0 non-null      float64
#  15  year          1161 non-null   int64
#  16  stats         1161 non-null   object
#  17  tags          1161 non-null   object
# ...

# %% [markdown]
# Retourne les colonnes avec leur type. Le type est inféré par le lecteur de csv.
# Les object sont généralement des string, le typpage des variables numériques est souvent le plus large possible.

# %% [markdown]
# ### Avoir un résumé statistique

# %%
df.describe()
# Out:
#              osm_id         lat         lon  website  phone  fax    year  \
# count  9.170000e+02  917.000000  917.000000      0.0    0.0  0.0  1161.0
# mean   1.538879e+09   45.991215    2.714602      NaN    NaN  NaN  2018.0
# std    2.163928e+09    6.806261    8.929845      NaN    NaN  NaN     0.0
# min    7.444000e+03  -34.603178  -61.537012      NaN    NaN  NaN  2018.0
# 25%    8.318416e+07   44.562265    1.076350      NaN    NaN  NaN  2018.0
# 50%    3.003413e+08   47.085087    2.830196      NaN    NaN  NaN  2018.0
# 75%    2.323052e+09   48.788486    5.054248      NaN    NaN  NaN  2018.0
# max    8.313179e+09   51.037887  135.832533      NaN    NaN  NaN  2018.0
#
#        description
# count          0.0
# mean           NaN
# std            NaN
# min            NaN
# 25%            NaN
# 50%            NaN
# 75%            NaN
# max            NaN

# %% [markdown]
# On voit que les variables non numériques sont sorties de la table.

# %%
df
# Out:
#            id        osm_id  \
# 0     0105302           NaN
# 1     0119201  1.357668e+09
# 2     0128301  1.536397e+09
# 3     0319002           NaN
# 4     0701001  4.424167e+09
# ...       ...           ...
# 1156  8400701  8.378474e+07
# 1157  8403503  5.111377e+09
# 1158  8403502           NaN
# 1159  8412301  7.494836e+08
# 1160  8413701  8.854919e+07
#
#                                                    name number  \
# 0                 Musée Départemental des Pays De l'Ain    NaN
# 1                                   Musée Archéologique    NaN
# 2                   Musée du Peigne et de la Plasturgie    NaN
# 3     Centre National du Costume de Scène et de la S...    NaN
# 4                           Musée Vivarois César Filhol     15
# ...                                                 ...    ...
# 1156         Muséum d'Histoire Naturelle Esprit Requien     27
# 1157                                        Musée Jouve    NaN
# ...

# %% [markdown]
# 📌 On va volontairement changer l'index pour ne pas confondre sur la prochaine section ce qui relève de l'indexage via à vis de la position, ou du nom.

# %%
## Question
df.index = range(len(df)*5)[::5]

# %% [markdown]
# ## Selectionner des sous ensemble de la DataFrame
#
# [Documentation officielle](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html)

# %% [markdown]
# #### Methodes simples

# %% [markdown]
# ### Colonnes

# %% [markdown]
# #### Selectionner une seule colonne
# 1. df["Nom_de_colonne"]
# 2. df.Nom_de_colonne

# %%
df["street"]
# Out:
# 0                                 NaN
# 5                   Place de l'Église
# 10             Rue Capitaine Montreal
# 15                                NaN
# 20      Rue Jean-Baptiste Bechetoille
#                     ...
# 5780             Rue de la République
# 5785                    Rue Hébraïque
# 5790                              NaN
# 5795                     Rue du Musée
# 5800                       Rue Burrus
# Name: street, Length: 1161, dtype: object

# %%
df.street
# Out:
# 0                                 NaN
# 5                   Place de l'Église
# 10             Rue Capitaine Montreal
# 15                                NaN
# 20      Rue Jean-Baptiste Bechetoille
#                     ...
# 5780             Rue de la République
# 5785                    Rue Hébraïque
# 5790                              NaN
# 5795                     Rue du Musée
# 5800                       Rue Burrus
# Name: street, Length: 1161, dtype: object

# %% [markdown]
# 1. Methode par slicing:
#     - des noms avec des espaces
#     - des noms de méthodes ou d'attributs d'une dataframe
#     - ne permet pas d'utiliser l'autocompletion
# 2. Methode par attribut:
#     - pas de noms avec espaces
#     - n'accède pas aux colonnes qui ont des noms de méthodes ou d'attributs d'une dataframe
#     - permet d'utiliser l'autocompletion

# %%
df_test = pd.DataFrame({"abs":[1,-2,-4,5]})

# %%
df_test.abs()
# Out:
#    abs
# 0    1
# 1    2
# 2    4
# 3    5

# %% [markdown]
# #### Selectionner plusieurs colonnes

# %%
df[["name", "city"]]
# Out:
#                                                    name               city
# 0                 Musée Départemental des Pays De l'Ain    BOURG-EN-BRESSE
# 5                                   Musée Archéologique           Izernore
# 10                  Musée du Peigne et de la Plasturgie            Veyziat
# 15    Centre National du Costume de Scène et de la S...            MOULINS
# 20                          Musée Vivarois César Filhol            Annonay
# ...                                                 ...                ...
# 5780         Muséum d'Histoire Naturelle Esprit Requien            Avignon
# 5785                                        Musée Jouve          Cavaillon
# 5790                              Musée de l'Hôtel Dieu          CAVAILLON
# 5795                                    Musée Municipal              Sault
# 5800                  Musée Archéologique Théo Desplans  Vaison-la-Romaine
#
# [1161 rows x 2 columns]

# %%
df.__getitem__(["name", "city"])
# Out:
#                                                    name               city
# 0                 Musée Départemental des Pays De l'Ain    BOURG-EN-BRESSE
# 5                                   Musée Archéologique           Izernore
# 10                  Musée du Peigne et de la Plasturgie            Veyziat
# 15    Centre National du Costume de Scène et de la S...            MOULINS
# 20                          Musée Vivarois César Filhol            Annonay
# ...                                                 ...                ...
# 5780         Muséum d'Histoire Naturelle Esprit Requien            Avignon
# 5785                                        Musée Jouve          Cavaillon
# 5790                              Musée de l'Hôtel Dieu          CAVAILLON
# 5795                                    Musée Municipal              Sault
# 5800                  Musée Archéologique Théo Desplans  Vaison-la-Romaine
#
# [1161 rows x 2 columns]

# %% [markdown]
# ### Lignes

# %% [markdown]
# On peut utiliser la notation en crochet comme pour une liste, pour slicer en fonction de la position de la ligne.

# %%
df[9:12]
# Out:
#          id        osm_id                                     name number  \
# 45  3818507  2.388639e+09                           Musée Stendhal     20
# 50  3818502  1.102624e+06                         Musée Dauphinois     30
# 55  3819001  1.869974e+09  Maison du Patrimoine de Hières-sur-Amby    NaN
#
#                  street postal_code             city country country_code  \
# 45           Grande Rue       38000         Grenoble  France           fr
# 50  Rue Maurice Gignoux       38031         Grenoble  France           fr
# 55    Montée de la Cure       38118  Hières-sur-Amby  France           fr
#
#    status        lat       lon  website  phone  fax  year  \
# 45   open  45.191580  5.728147      NaN    NaN  NaN  2018
# 50   open  45.195149  5.727072      NaN    NaN  NaN  2018
# 55   open  45.797051  5.293209      NaN    NaN  NaN  2018
#
#                                              stats                   tags  \
# ...

# %% [markdown]
# Si on applique la même méthode à une série, c'est également la position qui va être utilisée.

# %%
df.name[9:12]
# Out:
# 45                             Musée Stendhal
# 50                           Musée Dauphinois
# 55    Maison du Patrimoine de Hières-sur-Amby
# Name: name, dtype: object

# %% [markdown]
# #### Attention `df[9]` va rechercher une colonne qui aurait la valeur 9

# %%
df[9]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 9
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# #### Selection par index ou par position

# %% [markdown]
# Deux méthodes (canonique) pour sélectionner des sous ensemble de dataframe.
# `loc` et `iloc`.
#
# - `loc` permet de sélectionner par l'`index` pandas, en d'autre terme en fonction du "nom" de la ligne ou du nom de la colonne.
# - `iloc` permet de sélectionner par la *position*  (le `i` de `iloc` vient de ''integer position based'' )

# %%
df_disney = pd.DataFrame(
    [["Riri","Canard", 1937, .80],   
     ["Dingo", "Chien", 1932, 1.8],#### Ceci est un dictionnaire de dictionnaire
    ["Mickey",  "Souris", 1928, 1],
     ["Donald", "canard", np.nan, 1.05]
   ], columns=["nom", "Espece", "date_creation", "taille"]).set_index("nom")

# %%
df_disney
# Out:
#         Espece  date_creation  taille
# nom
# Riri    Canard         1937.0    0.80
# Dingo    Chien         1932.0    1.80
# Mickey  Souris         1928.0    1.00
# Donald  canard            NaN    1.05

# %%
df_disney.loc["Riri",:]  #Peut être raccourcie en .loc["Riri"]
# Out:
# Espece           Canard
# date_creation    1937.0
# taille              0.8
# Name: Riri, dtype: object

# %%
df_disney.iloc[0,:]
# Out:
# Espece           Canard
# date_creation    1937.0
# taille              0.8
# Name: Riri, dtype: object

# %% [markdown]
# Donc en utilisant loc et iloc, on slice la dataframe, le premier élément correspondant à la ligne, et le deuxième à la colonne.
#
# `.loc["start_row_name":"end_row_name", "start_column_name":"end_column_name"]`

# %%
df_disney.loc["Riri"] #Selectionne la ligne de Riri
df_disney.loc["Riri":"Mickey"] #Sélectionne les ligne de Riri à Mickey inclu...
df_disney.loc["Riri":"Mickey", "Espece":"date_creation" ] # Sélectionne les lignes de Riri à Michey et de Espece à date_creation
df_disney.loc[["Riri", "Donald", "Dingo"], ["Espece", "taille"]]
# Out:
#         Espece  taille
# nom
# Riri    Canard    0.80
# Donald  canard    1.05
# Dingo    Chien    1.80

# %%
df_disney.iloc[0:2, -2:]
# Out:
#        date_creation  taille
# nom
# Riri          1937.0     0.8
# Dingo         1932.0     1.8

# %%
df_disney.loc["Riri":"Mickey", "Espece":"date_creation" ]
# Out:
#         Espece  date_creation
# nom
# Riri    Canard         1937.0
# Dingo    Chien         1932.0
# Mickey  Souris         1928.0

# %% [markdown]
# ### Purpose selected obs

# %%
df.head()
df.tail()
df.sample()
# Out:
#            id  osm_id                      name number street postal_code  \
# 3105  5055101     NaN  Musée Barbey d'Aurevilly    NaN    NaN         NaN
#
#                           city country country_code status  lat  lon  website  \
# 3105  SAINT-SAUVEUR-LE-VICOMTE  France           fr   open  NaN  NaN      NaN
#
#       phone  fax  year                                         stats  \
# 3105    NaN  NaN  2018  payant:686;gratuit:451;label-date:01/02/2003
#
#                        tags  description
# 3105  label:musee de france          NaN

# %% [markdown]
# ### Sélectionner le musée le plus au sud

# %%
df.lat.idxmin?
# Out:
# Signature: df.lat.idxmin(axis=0, skipna=True, *args, **kwargs)
# Docstring:
# Return the row label of the minimum value.
#
# If multiple values equal the minimum, the first row label with that
# value is returned.
#
# Parameters
# ----------
# axis : int, default 0
#     For compatibility with DataFrame.idxmin. Redundant for application
#     on Series.
# skipna : bool, default True
#     Exclude NA/null values. If the entire Series is NA, the result
#     will be NA.
# *args, **kwargs
#     Additional arguments and keywords have no effect but might be
#     accepted for compatibility with NumPy.
#
# Returns
# -------
# Index
#     Label of the minimum value.
#
# Raises
# ------
# ValueError
#     If the Series is empty.
#
# See Also
# --------
# numpy.argmin : Return indices of the minimum values
#     along the given axis.
# DataFrame.idxmin : Return index of first occurrence of minimum
#     over requested axis.
# Series.idxmax : Return index *label* of the first occurrence
# ...

# %%
df.lat.min()
# Out:
# -34.603178

# %%
df.lat.idxmin() ## Return row label
# Out:
# 1720

# %%
df.loc[df.lat.idxmin()]
# Out:
# id                                               6216004
# osm_id                                        18822516.0
# name                         Muséum d'Histoire Naturelle
# number                                               NaN
# street                                  Boulogne Sur Mer
# postal_code                                     C1187AAN
# city                                        Buenos Aires
# country                                        Argentina
# country_code                                          ar
# status                                            closed
# lat                                           -34.603178
# lon                                           -58.406302
# website                                              NaN
# phone                                                NaN
# fax                                                  NaN
# year                                                2018
# ...

# %%
### Ou plus simplement (mais potentiellement mois performant ?)
df.sort_values("lat").iloc[0]
# Out:
# id                                               6216004
# osm_id                                        18822516.0
# name                         Muséum d'Histoire Naturelle
# number                                               NaN
# street                                  Boulogne Sur Mer
# postal_code                                     C1187AAN
# city                                        Buenos Aires
# country                                        Argentina
# country_code                                          ar
# status                                            closed
# lat                                           -34.603178
# lon                                           -58.406302
# website                                              NaN
# phone                                                NaN
# fax                                                  NaN
# year                                                2018
# ...

# %% [markdown]
# ### Résumé dans la documentation

# %% [markdown]
# <img src='./images/select_data_methods.png'></img>

# %% [markdown]
# #### Modifier une ou plusieurs valeurs

# %%
df.loc[0, "name"] = "Muahahahaha"

# %%
df.head()
# Out:
#          id        osm_id                                               name  \
# 0   0105302           NaN                                        Muahahahaha
# 5   0119201  1.357668e+09                                Musée Archéologique
# 10  0128301  1.536397e+09                Musée du Peigne et de la Plasturgie
# 15  0319002           NaN  Centre National du Costume de Scène et de la S...
# 20  0701001  4.424167e+09                        Musée Vivarois César Filhol
#
#    number                         street postal_code             city country  \
# 0     NaN                            NaN         NaN  BOURG-EN-BRESSE  France
# 5     NaN              Place de l'Église       01580         Izernore  France
# 10    NaN         Rue Capitaine Montreal       01100          Veyziat  France
# 15    NaN                            NaN         NaN          MOULINS  France
# 20     15  Rue Jean-Baptiste Bechetoille       07100          Annonay  France
#
# ...

# %%
df.loc[2:10, "city"] = "Gotham city"

# %%
df.head()
# Out:
#          id        osm_id                                               name  \
# 0   0105302           NaN                                        Muahahahaha
# 5   0119201  1.357668e+09                                Musée Archéologique
# 10  0128301  1.536397e+09                Musée du Peigne et de la Plasturgie
# 15  0319002           NaN  Centre National du Costume de Scène et de la S...
# 20  0701001  4.424167e+09                        Musée Vivarois César Filhol
#
#    number                         street postal_code             city country  \
# 0     NaN                            NaN         NaN  BOURG-EN-BRESSE  France
# 5     NaN              Place de l'Église       01580      Gotham city  France
# 10    NaN         Rue Capitaine Montreal       01100      Gotham city  France
# 15    NaN                            NaN         NaN          MOULINS  France
# 20     15  Rue Jean-Baptiste Bechetoille       07100          Annonay  France
#
# ...
