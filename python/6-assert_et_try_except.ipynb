# %% [markdown]
# ## Les erreurs en Python

# %% [markdown]
# Quand on code, si on code suffisamment longtemps on va être confronté à des erreurs:
# 1. Les erreurs que l'on veut passer sans casser notre programme
# 2. Les erreurs qui doivent terminer les programme

# %% [markdown]
# ### Try-Except (finally)
# Quand on a une erreur que l'on veut passer sans casser notre programme.
#
# doc python officielle : https://docs.python.org/3/tutorial/errors.html

# %%
try:
    print("Coucou " + "hello")
except:
    print("bouuuu")
# Out:
# Coucou hello

# %%
try:
    print(3 + "hello")
except:
    print("bouuuu")
# Out:
# bouuuu

# %% [markdown]
# ---------

# %% [markdown]
# ##### Printer l'exception si on veut savoir pourquoi cela n'a pas marché

# %%
try:
    print(3 + "hello")
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    print(3 + "hello")
except Exception as e:
    print(repr(e))
    print("coucou")
print("goodbye")
# Out:
# TypeError("unsupported operand type(s) for +: 'int' and 'str'")
# coucou
# goodbye

# %% [markdown]
# #### Lever l'exception que si c'est bien l'exception que l'on attend qui a été levée

# %%
try:
    print(3 + variable_non_definie)
    print(3 + "hello")
except TypeError as e:
    print(e)
print("coucou")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 try:
# ----> 2     print(3 + variable_non_definie)
#       3     print(3 + "hello")
#       4 except TypeError as e:
#
# NameError: name 'variable_non_definie' is not defined

# %%
try:
    print(3 + variable_non_definie)
    print(3 + "hello")
except (TypeError, NameError) as e:
    print(e)
print("coucou")
# Out:
# name 'variable_non_definie' is not defined
# coucou

# %%
try:
    import un_package_qui_nexiste_pas
    print(3 + "hello")
except TypeError as e:
    print(e)
print(e)
print("Coucou !")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 try:
# ----> 2     import un_package_qui_nexiste_pas
#       3     print(3 + "hello")
#       4 except TypeError as e:
#
# ModuleNotFoundError: No module named 'un_package_qui_nexiste_pas'

# %%
try:
    import un_package_qui_nexiste_pas
    print(3 + "hello")
except (TypeError, ModuleNotFoundError) as e:
    print(e)
print("coucou")
# Out:
# No module named 'un_package_qui_nexiste_pas'
# coucou

# %% [markdown]
# #### Mais pour quoi faire ?

# %%
b = 3
while True:
    a = input("renseignez quoi ajouter à b: ")
    try:
        a = float(a)
    except ValueError:
        pass
    try:
        print(a + b)
        print("l'école est finie !")
        break
    except TypeError as e:
        #print(e)
        print("On ne peut pas additionner les int et les string, mais la vie continue ☀️ !")
# Out:
# renseignez quoi ajouter à b:  3
# 6.0
# l'école est finie !

# %%
b = 3
while True:
    a = input("renseignez quoi ajouter à b: ")

    try:
        print(float(a) + b)
        print("l'école est finie !")
        break
    except(TypeError,ValueError) as e:
        #print(e)
        print("On ne peut pas additionner les int et les string, mais la vie continue ☀️ !")
# Out:
# renseignez quoi ajouter à b:  coucou
# On ne peut pas additionner les int et les string, mais la vie continue ☀️ !
# renseignez quoi ajouter à b:  coucou
# On ne peut pas additionner les int et les string, mais la vie continue ☀️ !
# renseignez quoi ajouter à b:  12
# 15.0
# l'école est finie !

# %%
float("32e10")
# Out:
# 320000000000.0

# %% [markdown]
# Mais en data science ?

# %%
import os

# %%
import pandas as pd
from urllib.error import URLError
#from IPython.display import display
import os
try:
    df = pd.read_csv(
        "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/"
        +"dpc-covid19-ita-province-20200225.csv")
    try:
        os.mkdir("./data")
    except FileExistsError:
        print("Folder already exists")
        
    df.to_csv("./data/covid_italie.csv")
    display(df)
except URLError: #imaginons que le csv soit supprimé par l'utilisateur
    print("URL ERROR, va lire le fichier en cache")
    df = pd.read_csv("./data/covid_italie.csv")

    display(df)
# Out:
# Folder already exists
#                     data stato  codice_regione denominazione_regione  \
# 0    2020-02-25T18:00:00   ITA              13               Abruzzo
# 1    2020-02-25T18:00:00   ITA              13               Abruzzo
# 2    2020-02-25T18:00:00   ITA              13               Abruzzo
# 3    2020-02-25T18:00:00   ITA              13               Abruzzo
# 4    2020-02-25T18:00:00   ITA              13               Abruzzo
# ..                   ...   ...             ...                   ...
# 123  2020-02-25T18:00:00   ITA               5                Veneto
# 124  2020-02-25T18:00:00   ITA               5                Veneto
# 125  2020-02-25T18:00:00   ITA               5                Veneto
# 126  2020-02-25T18:00:00   ITA               5                Veneto
# 127  2020-02-25T18:00:00   ITA               5                Veneto
#
#      codice_provincia               denominazione_provincia sigla_provincia  \
# ...

# %% [markdown]
# Écrivez une fonction de mise en cache d'un fichier csv qui est en ligne.
# - Si le fichier est enregistré, ne pas le télécharger et le lire.
# - Si le fichier n'est pas enregistré, le télécharger/lire, et l'enregistrer.

# %%
url = "https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province-20200225.csv"

# %%
def mise_en_cache_fichier_csv(url_csv, file_path=None):
    """une docstring
    Lis une url de fichier csv en ligne
    sauf si le fichier est déjà enregistré
    dans ce cas là, le lis localement
    ----
    return
    DataFrame
    """
    try:
        df = pd.read_csv(file_path)
    except FileNotFoundError:
        print("pas lu le csv sur l'ordinateur")
        df = pd.read_csv(url_csv)
        df.to_csv(file_path,index=False)
    return df

# %%
import pandas as pd

# %%
df = pd.read_csv(url)
df.to_csv("fihchier_exercice_cache.csv")

# %%
try:
    df = pd.read_csv("fihchier_exercice_cache.csv")
except FileNotFoundError:
    print("pas lu le csv sur l'ordinateur")
    df = pd.read_csv(url)
    df.to_csv("fihchier_exercice_cache.csv",index=False)

# %%
df_save = df.copy()

# %%
df.head()
# Out:
#                   data stato  codice_regione denominazione_regione  \
# 0  2020-02-25T18:00:00   ITA              13               Abruzzo
# 1  2020-02-25T18:00:00   ITA              13               Abruzzo
# 2  2020-02-25T18:00:00   ITA              13               Abruzzo
# 3  2020-02-25T18:00:00   ITA              13               Abruzzo
# 4  2020-02-25T18:00:00   ITA              13               Abruzzo
#
#    codice_provincia               denominazione_provincia sigla_provincia  \
# 0                66                              L'Aquila              AQ
# 1                67                                Teramo              TE
# 2                68                               Pescara              PE
# 3                69                                Chieti              CH
# 4               979  In fase di definizione/aggiornamento             NaN
#
#          lat       long  totale_casi  note
# 0  42.351222  13.398438            0   NaN
# ...

# %%
df_save.head()
# Out:
#                   data stato  codice_regione denominazione_regione  \
# 0  2020-02-25T18:00:00   ITA              13               Abruzzo
# 1  2020-02-25T18:00:00   ITA              13               Abruzzo
# 2  2020-02-25T18:00:00   ITA              13               Abruzzo
# 3  2020-02-25T18:00:00   ITA              13               Abruzzo
# 4  2020-02-25T18:00:00   ITA              13               Abruzzo
#
#    codice_provincia               denominazione_provincia sigla_provincia  \
# 0                66                              L'Aquila              AQ
# 1                67                                Teramo              TE
# 2                68                               Pescara              PE
# 3                69                                Chieti              CH
# 4               979  In fase di definizione/aggiornamento             NaN
#
#          lat       long  totale_casi  note
# 0  42.351222  13.398438            0   NaN
# ...

# %% [markdown]
# Il est normalement conseillé de définir l'erreur(s) levée(s) pour définir l'exception.
# Sur une librairie/base de code conséquente, ça facilite le déboguage et permettra au programme de crasher si une erreur non prévue arrive.
#
# Sur de la data science en jupyter notebook ¯\_(ツ)_/¯ (on gagne du temps a ne pas les définir et à priori on fera quelque chose de plus propre en production).

# %% [markdown]
# ## Les asserts

# %%
assert 3==3

# %%
assert 3 == 4
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 assert 3 == 4
#
# AssertionError:

# %% [markdown]
# Un assert s'assure qu'une condition est vraie pour que le programme continue.

# %% [markdown]
# Mais à quoi ça sert ?:
# 1. Permet de faire en sorte que le code casse s'il ne se comporte pas comme prévu
# 2. Permet d'auto-documenter son code
#
#
# Utiliser beaucoup d'assert est une bonne chose.
#
#
#
# Il est même souvent utile d'écrire un assert (un test) pour définir ce que l'on veut  que le code fasse, avant d'écrire le code : c'est la base du **Test driven development**.

# %% [markdown]
# Mais à quoi ça peut servir en data science ?
#
# C'est souvent utile pour tester les données. Par exemple qu'après des manipulations, le nombre d'observation soit égal aux observations espérées (surtout après des merge).

# %%
df = pd.read_csv("https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province-20200225.csv")

assert len(df)>2000 #ici on teste que l'on a au moins 20 lignes dans la table téléchargée
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[32], line 3
#       1 df = pd.read_csv("https://raw.githubusercontent.com/pcm-dpc/COVID-19/master/dati-province/dpc-covid19-ita-province-20200225.csv")
# ----> 3 assert len(df)>2000
#
# AssertionError:

# %% [markdown]
# C'est aussi la base des tests unitaire (ou d'intégration) qui permet de faire du CI (jenkins, Travis, Gitlab et Github CI etc).
# C'est une des bases importantes du [MLOps](https://en.wikipedia.org/wiki/MLOps)

# %% [markdown]
# [travis](https://travis-ci.org/github/adrienpacifico/adrienpacifico.github.io/builds/768587169)

# %% [markdown]
# ### Exemple de TDD avec pytest pour faire un mini ci

# %% [markdown]
# En TDD on écrit les tests d'abord !

# %%
# %pip install ipytest
# Out:
# ...
#   Using cached pytest-7.4.3-py3-none-any.whl.metadata (7.9 kB)
# ...
#   Using cached iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# ...
#   Using cached pluggy-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# ...
# Using cached pytest-7.4.3-py3-none-any.whl (325 kB)
# Using cached pluggy-1.3.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipytest
ipytest.autoconfig()

# %% [markdown]
# On va faire une fonction qui crée une division entière.
# On va l'appelerè `division_entiere`

# %%
def division_entiere(quotient, dividend):
    return quotient//dividend

# %%
isinstance(4//0, ZeroDivisionError)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 isinstance(4//0, ZeroDivisionError)
#
# ZeroDivisionError: integer division or modulo by zero

# %%
# %%ipytest
# def test_division_entiere_type():
#     assert isinstance(division_entiere(10,5), int)
# def test_division_entiere_result_1():
#     assert division_entiere(10,2) == 5
# def test_division_entiere_negative():
#     assert division_entiere(-10,2) == -5
# def test_division_entiere_with_rest():
#     assert division_entiere(11,2) == 5
# def test_error_if_divide_by_zero():
#     try:
#         4//0
#     except Exception as e:
#         print(e)
#         assert str(e) == 'integer division or modulo by zero'
# Out:
# .....                                                                                        [100%]
# 5 passed in 0.01s

# %% [markdown]
# On a bien une fonction de division entière qui fonctionne.
# Maintenant l'utilisateur nous demande de modifier la fonction pour accepter des nombre en string dans la fonction.

# %%
def division_entiere(quotient, dividend):
    quotient = int(quotient)
    dividend = int(dividend)
    return quotient//dividend

# %% [markdown]
# Modifier la fonction et écrivez le tests pour que:
# - la fonction marche avec des nombres non entiers
# - la fonction marche avec des nombres en string
# _____
# - la fonction marche avec des nombres en toute lettres
# `division_entiere("onze", "deux") == 5`, pour cela vous pourrez vous aider de la librairie `text2num`

# %%
# %pip install text2num
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for text2num: filename=text2num-2.5.0-py3-none-any.whl size=58659 sha256=7b2e54591ca815e1de8aaf9954ca8c487c6affa06f229d116990955de2a6f291
#   Stored in directory: /Users/adrienpacifico/Library/Caches/pip/wheels/ac/04/76/d6d128340a3efc998468fd8da42f3b8148ab466fa735fdd726
# Successfully built text2num
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from text_to_num import text2num
text2num("mille neuf cents quatre-vingt dix","fr")
# Out:
# 1990

# %%
# %%ipytest
# def test_division_entiere_type():
#     assert isinstance(division_entiere(10,5), int)
# def test_division_entiere_result_1():
#     assert division_entiere(10,2) == 5
# def test_division_entiere_negative():
#     assert division_entiere(-10,2) == -5
# def test_division_entiere_with_rest():
#     assert division_entiere(11,2) == 5
# def test_error_if_divide_by_zero():
#     try:
#         4//0
#     except Exception as e:
#         print(e)
#         assert str(e) == 'integer division or modulo by zero'
# def test_nombre_en_string_1():
#     assert division_entiere("10","2") == 5
# def test_nombre_en_string_2():
#     assert division_entiere("11","2") == 5
# def test_div_nombre_non_entiers():
#     assert division_entiere(25,2.9) == 8
# Out:
# .......F                                                                                     [100%]
# ============================================= FAILURES =============================================
# ___________________________________ test_div_nombre_non_entiers ____________________________________
#
#     def test_div_nombre_non_entiers():
# >       assert division_entiere(25,2.9) == 8
# E       assert 12 == 8
# E        +  where 12 = division_entiere(25, 2.9)
#
# /var/folders/l5/p4f2y4qd0jj4n34zysyp82540000gn/T/ipykernel_17776/1692442340.py:20: AssertionError
# ===================================== short test summary info ======================================
# FAILED t_c5ea571a7f9c488b8c51e2dfa7f36c21.py::test_div_nombre_non_entiers - assert 12 == 8
# 1 failed, 7 passed in 0.02s

# %%
# %%ipytest
#
# # define the tests
#
# def test_my_func1():
#     assert my_func(37,6) == 12
# def test_my_func2():
#     assert my_func(36, 6) == 12

# %%
def return_none():
    return None

# %%
assert return_none() is None

# %%
2==None
# Out:
# False

# %%
# %pip install text2num
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for text2num: filename=text2num-2.5.0-py3-none-any.whl size=58659 sha256=d134075c3d0384f9bd958c37ad4323348783d4f4ae90798fcccfaa2593dcebf4
#   Stored in directory: /home/jovyan/.cache/pip/wheels/ac/04/76/d6d128340a3efc998468fd8da42f3b8148ab466fa735fdd726
# Successfully built text2num
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from text_to_num import text2num
text2num("cinq","fr")
# Out:
# 5

# %%
# Out:
# 1990

# %%
import ipytest
ipytest.autoconfig()

# %%
hab_surface_by_ville = {"Marseille":{"nombre_habitants":200_000,"surface":6*10**7}, "Paris":{"nombre_habitants":400_000,"surface":10**7},
"Montfort":{"nombre_habitants":0,"surface":10_000}, "Dijon":{"nombre_habitants":"200_000","surface":"60_000_000"},
                        "Troyes":{"nombre_habitants":"dix milles","surface":"un million"}
                       }

# %%
for ville in hab_surface_by_ville.keys():
    print(ville)
    hab_surface_by_ville[ville]["m2_par_habitants"] = division_entiere(
                                     hab_surface_by_ville[ville]["surface"],
                                    hab_surface_by_ville[ville]["nombre_habitants"],
                                                        )
print(hab_surface_by_ville)
# Out:
# Mrseille
# Paris
# Montfort
# Dijon
# Troyes
# {'Mrseille': {'nombre_habitants': 200000, 'surface': 60000000, 'm2_par_habitants': 300}, 'Paris': {'nombre_habitants': 400000, 'surface': 10000000, 'm2_par_habitants': 25}, 'Montfort': {'nombre_habitants': 0, 'surface': 10000, 'm2_par_habitants': None}, 'Dijon': {'nombre_habitants': '200_000', 'surface': '60_000_000', 'm2_par_habitants': 300}, 'Troyes': {'nombre_habitants': 'dix milles', 'surface': 'un million', 'm2_par_habitants': 100}}

# %%
def division_entiere(dividende, diviseur):
    if diviseur == 0:
        return None
    else:
        return int(dividende)//int(diviseur)

# %%
from text_to_num import text2num
text2num("mille neuf cents quatre-vingt dix","fr")
# Out:
# 1990

# %%
def division_entiere(dividende, diviseur):
    if diviseur == 0:
        return None
    else:
        try:
            return int(dividende)//int(diviseur)
        except ValueError:
            dividende = text2num(dividende,"fr")
            diviseur = text2num(diviseur,"fr")
            return dividende//diviseur

# %%
# %%ipytest
# def test_division_entiere_0():
#     assert division_entiere(10,5) == 2
# def test_division_entiere_01():
#     assert division_entiere(6,2) == 3
# def test_division_entiere_1():
#     assert division_entiere(13,2) == 6
# def test_division_entiere_2():
#     assert division_entiere(15,2) == 7
# def test_division_entiere_par_zero():
#     assert division_entiere(23,0) is None
#
#
# def test_division_entiere_avec_string_1():
#     assert division_entiere(10,"5") == 2
# def test_division_entiere_avec_string_2():
#     assert division_entiere("10",5) == 2
# def test_division_entiere_avec_string_3():
#     assert division_entiere("10","0") is None
# def test_division_entiere_avec_nombre_en_lettres_0():
#     assert division_entiere("dix","cinq") == 2
# def test_division_entiere_avec_nombre_en_lettres_1():
#     assert division_entiere("un million","dix mille") == 100
# def test_division_entiere_avec_nombre_en_lettres_1():
#     assert division_entiere("mille neuf cent quatre-vingt-dix-neuf",
#                             "quatre cent vingt-quatre") == 4
# def test_division_entiere_avec_string_0():
#     assert division_entiere("10","5") == 2
# def test_division_entiere_avec_1nombre_en_lettres_autre_en_int():
#     assert division_entiere("dix",5) == 2
# Out:
# .........FF                                                                                  [100%]
# ============================================= FAILURES =============================================
# __________________________ test_division_entiere_avec_nombre_en_lettres_0 __________________________
#
#     def test_division_entiere_avec_nombre_en_lettres_0():
# >       assert division_entiere("dix","cinq") == 2
#
# /tmp/ipykernel_39813/1652768601.py:21:
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# dividende = 'dix', diviseur = 'cinq'
#
#     def division_entiere(dividende, diviseur):
# >       if int(diviseur) == 0:
# E       ValueError: invalid literal for int() with base 10: 'cinq'
#
# /tmp/ipykernel_39813/667153445.py:2: ValueError
# __________________________ test_division_entiere_avec_nombre_en_lettres_1 __________________________
#
#     def test_division_entiere_avec_nombre_en_lettres_1():
# ...

# %%
# %pip install inflect
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.8/395.8 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 7.5 MB/s eta 0:00:00a 0:00:01m
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# #### Exemple général

# %%
def my_func(x):
    return (x // 2) * 2

# %%
(37//6)*2
# Out:
# 12

# %%
def my_func(x, y):
    """
    Fait division entière par 
    et multiplie le résultat par 2
    """
    return (x // y) * 2

# %%
my_func(43,2)
# Out:
# 42

# %%
# %%ipytest
#
# # define the tests
#
# def test_my_func1():
#     assert my_func(37,6) == 12
# def test_my_func2():
#     assert my_func(36, 6) == 12
# def test_my_func3():
#     assert my_func(40, 6) == 12
# def test_my_func4():
#     assert my_func(43,2) == 42
# def test_my_func5():
#     assert my_func(64,2) == 64
# def test_my_func6():
#     assert my_func(65,2) == 64
#
#
#
# def my_func(x,y):
#     """
#     Fait division entière par
#     et multiplie le résultat par 2
#     """
#     return 2 * (x // y)
# Out:
# ......                                                                                       [100%]
# 6 passed in 0.01s

# %%
# %%ipytest
#
# import pytest
#
# def my_func(x):
#     """
#     Fait division entière par
#     et multiplie le résultat par 2
#     """
#     return (x // 2)*2
#
# @pytest.mark.parametrize('input,expected', [
#     (0, 0),
#     (1, 0),
#     (2, 2),
#     (3, 2),
# ])
# def test_parametrized(input, expected):
#     assert my_func(input) == expected
#
# @pytest.fixture
# def my_fixture():
#     return 42
#
#
# def test_fixture(my_fixture):
#     assert my_fixture == 42
# Out:
# .....                                                                                        [100%]
# 5 passed in 0.01s

# %% [markdown]
# Exemple appliqué :

# %%
#On écrit ce que l'on veut que la fonction fasse

def download_or_load(url=None, cache_path="./data"):
    """
    Télécharge un csv via une url en ligne
    À défaut, charge la données correspondante en cache
    """

# %%
### test download_or_load si la donnée est disponible
def test_dowload_or_load_if_correct_url():
    """
    1- Crée le dossier /data s'il n'existe pas
    2- Essaye de télécharger un csv via un lien qui marche et retourne 
    """

# %%
### Terminer, puis faire un exemple ou on veut rajouter que l'on veut que des url qui se terminent pas csv
