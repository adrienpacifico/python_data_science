# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/adrienpacifico/Projects/cours/python_data_science/01_python/01_python_debutant'

# %%
os.listdir()
# Out:
# ['2-zen_of_python.ipynb',
#  'Introduction.ipynb',
#  'exercices',
#  '0-Mettre_en_place_son_environnement_jupyter.ipynb',
#  '.DS_Store',
#  '1-python_introduction.ipynb',
#  '.pytest_cache',
#  'fichier_exercice_cache.csv',
#  '6-assert_et_try_except.ipynb',
#  'Untitled.ipynb',
#  '5-View_vs_copy.ipynb',
#  '4-Functions.ipynb',
#  '00_comprehension_list_dict.ipynb',
#  '7-os.ipynb',
#  '.ipynb_checkpoints',
#  'test_ex_term.py',
#  'data',
#  '3-load_modules.ipynb',
#  '8-booléen_et_operateurs.ipynb',
#  '999-exporter_son_environnement',
#  'print_hello.txt']

# %%
os.listdir("../")
# Out:
# ['.DS_Store',
#  '.pytest_cache',
#  '02_python_intermediaire',
#  '.ipynb_checkpoints',
#  '01_python_debutant',
#  '03_python_avance']

# %%
os.chdir('../../02_dataframes')
os.listdir()
# Out:
# ['01_pandas', '.DS_Store', 'others', '02_polars', '.ipynb_checkpoints']

# %%
os.chdir('../01_python/01_python_debutant')
os.getcwd()
# Out:
# '/Users/adrienpacifico/Projects/cours/python_data_science/01_python/01_python_debutant'

# %%
os.getcwd()
# Out:
# '/Users/adrienpacifico/Projects/cours/python_data_science/01_python/01_python_debutant'

# %%
os.mkdir("data")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 os.mkdir("data")
#
# FileExistsError: [Errno 17] File exists: 'data'

# %%
os.mkdir("data2")

# %%
os.rmdir("data2")

# %%
mypath = os.getcwd()

# %% [markdown]
# ### Lister tous les fichiers dans un dossier

# %%
from os import walk
path, dir_in_path, filenames_in_path = next(walk(mypath))

# %%
next(walk(mypath))
# Out:
# ('/Users/adrienpacifico/Projects/cours/python_data_science/01_python/01_python_debutant',
#  ['exercices',
#   '.pytest_cache',
#   '.ipynb_checkpoints',
#   'data',
#   'data2',
#   '999-exporter_son_environnement'],
#  ['2-zen_of_python.ipynb',
#   'Introduction.ipynb',
#   '0-Mettre_en_place_son_environnement_jupyter.ipynb',
#   '.DS_Store',
#   '1-python_introduction.ipynb',
#   'fichier_exercice_cache.csv',
#   '6-assert_et_try_except.ipynb',
#   'Untitled.ipynb',
#   '5-View_vs_copy.ipynb',
#   '4-Functions.ipynb',
#   '00_comprehension_list_dict.ipynb',
#   '7-os.ipynb',
#   'test_ex_term.py',
#   '3-load_modules.ipynb',
#   '8-booléen_et_operateurs.ipynb',
#   'print_hello.txt'])

# %%
os.listdir()
# Out:
# ['7-os.ipynb',
#  '0-Mettre_en_place_son_environnement_jupyter.ipynb',
#  'test_ex_term.py',
#  '3-load_modules.ipynb',
#  'data',
#  'print_hello.txt',
#  '1-python_introduction.ipynb',
#  '.pytest_cache',
#  '8-booléen_et_operateurs.ipynb',
#  '5-View_vs_copy.ipynb',
#  '4-Functions.ipynb',
#  '6-assert_et_try_except.ipynb',
#  '.ipynb_checkpoints',
#  '2-zen_of_python.ipynb',
#  '999-exporter_son_environnement',
#  'Introduction.ipynb',
#  'fihchier_exercice_cache.csv']

# %%
filenames
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 filenames
#
# NameError: name 'filenames' is not defined

# %% [markdown]
# #### Exercice:
#
# Faire une fonction en utilisant walk pour lister tous les fichiers situés dans les dossiers et sous-dossiers (et sous-sous-... dossiers) pour un path donné.
